# %%
import mlrun
from mlrun import  get_or_create_project
project_name = "feature-sets"
project = get_or_create_project(project_name, context="./")
# Out:
# > 2024-09-03 13:33:54,912 [info] Project loaded successfully: {"project_name":"fs"}

# %%
import mlrun.feature_store as fs
from mlrun.feature_store.steps import *
from mlrun.features import MinMaxValidator
from mlrun.datastore.targets import ParquetTarget, NoSqlTarget,CSVTarget

# %%
import pandas as pd
quotes = pd.DataFrame(
    {
        "time": [
            pd.Timestamp("2016-05-25 13:30:00.023"),
            pd.Timestamp("2016-05-25 13:30:00.023"),
            pd.Timestamp("2016-05-25 13:30:00.030"),
            pd.Timestamp("2016-05-25 13:30:00.041"),
            pd.Timestamp("2016-05-25 13:30:00.048"),
            pd.Timestamp("2016-05-25 13:30:00.049"),
            pd.Timestamp("2016-05-25 13:30:00.072"),
            pd.Timestamp("2016-05-25 13:30:00.075")
        ],
        "ticker": [
               "GOOG",
               "MSFT",
               "MSFT",
               "MSFT",
               "GOOG",
               "AAPL",
               "GOOG",
               "MSFT"
           ],
           "bid": [720.50, 51.95, 51.97, 51.99, 720.50, 97.99, 720.50, 52.01],
           "ask": [720.93, 51.96, 51.98, 52.00, 720.93, 98.01, 720.88, 52.03],
    }
)

trades = pd.DataFrame(
       {
           "time": [
               pd.Timestamp("2016-05-25 13:30:00.023"),
               pd.Timestamp("2016-05-25 13:30:00.038"),
               pd.Timestamp("2016-05-25 13:30:00.048"),
               pd.Timestamp("2016-05-25 13:30:00.048"),
               pd.Timestamp("2016-05-25 13:30:00.048")
           ],
           "ticker": ["MSFT", "MSFT", "GOOG", "GOOG", "AAPL"],
           "price": [51.95, 51.95, 720.77, 720.92, 98.0],
           "quantity": [75, 155, 100, 100, 100]
       }
)


stocks = pd.DataFrame(
       {
           "ticker": ["MSFT", "GOOG", "AAPL"],
           "name": ["Microsoft Corporation", "Alphabet Inc", "Apple Inc"],
           "exchange": ["NASDAQ", "NASDAQ", "NASDAQ"]
       }
)

# %%
import datetime
def move_date(df, col):
    max_date = df[col].max()
    now_date = datetime.datetime.now()
    delta = now_date - max_date 
    df[col] = df[col] + delta 
    return df

# %%
quotes = move_date(quotes, "time")
trades = move_date(trades, "time")

# %% [markdown]
# ## Creating fs with 5 tags

# %%
import mlrun.feature_store as fs
from mlrun.feature_store import FeatureSet, Entity
for i in range(5):
    quotes_set = fs.FeatureSet("quotes", "my_quotes_description1234567890",entities=[fs.Entity("ticker")], timestamp_key= "time")
    quotes_set.metadata.labels = {'label-key1': 'label-value1','label-key2': 'label-value2','label-key3': 'label-value3','label-key4': 'label-value4','label-key5': 'label-value5','label-key6': 'label-value6','label-key7': 'label-value7','label-key7': 'label-value7','label-key9': 'label-value9','label-key10': 'label-value10'}
    #quotes_set.set_targets()
    partition_cols = ['ask', '$key']
    targets = [ParquetTarget(partitioned=True, partition_cols=partition_cols), NoSqlTarget(), CSVTarget() ]
    quotes_set.spec.label_column= 'ticker'
    quotes_set.spec.partition_keys = 'ticker'
    quotes_set.spec.relations={'key':'value','key2':'value2'}
    quotes_set["bid"] = fs.Feature(description= "desc_bid",labels= {'bid-key1': 'bid-value1'}, validator=MinMaxValidator(min=55, severity="info"))
    quotes_set.save(tag='tag'+str(i), versioned=True)
    ingest_df = fs.ingest(quotes_set, quotes, targets, infer_options=fs.InferOptions.default())

# %% [markdown]
# ## Creating fv

# %%
features = [
    "quotes.*"
]

vector = fs.FeatureVector("vector-name",features=features,description="this is my vector")
vector.metadata.labels = {'label-key1': 'label-value1','label-key2': 'label-value2','label-key3': 'label-value3',}
svc = vector.get_online_feature_service()
resp = svc.get([{"ticker": "MSFT"}, {"ticker": "AAPL"}])
try:
    resp1 = vector.get_offline_features()
except:
    print("Error occurred")
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[34], line 9
#       7 svc = vector.get_online_feature_service()
#       8 resp = svc.get([{"ticker": "MSFT"}, {"ticker": "AAPL"}])
# ----> 9 resp1 = vector.get_offline_features()
#
# File ~/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/feature_store/feature_vector.py:810, in FeatureVector.get_offline_features(self, entity_rows, entity_timestamp_column, target, run_config, drop_columns, start_time, end_time, with_indexes, update_stats, engine, engine_args, query, order_by, spark_service, timestamp_for_filtering, additional_filters)
#     727 def get_offline_features(
#     728     self,
#     729     entity_rows=None,
#    (...)
#     744     additional_filters: list = None,
#     745 ):
#     746     """retrieve offline feature vector results
#     747
#     748     specify a feature vector object/uri and retrieve the desired features, their metadata
#    (...)
#     807
#     808     """
# --> 810     return mlrun.feature_store.api._get_offline_features(
#     811         self,
#     812         entity_rows,
#     813         entity_timestamp_column,
#     814         target,
#     815         run_config,
#     816         drop_columns,
#     817         start_time,
#     818         end_time,
#     819         with_indexes,
#     820         update_stats,
#     821         engine,
#     822         engine_args,
#     823         query,
#     824         order_by,
#     825         spark_service,
#     826         timestamp_for_filtering,
#     827         additional_filters,
#     828     )
#
# File ~/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/feature_store/api.py:269, in _get_offline_features(feature_vector, entity_rows, entity_timestamp_column, target, run_config, drop_columns, start_time, end_time, with_indexes, update_stats, engine, engine_args, query, order_by, spark_service, timestamp_for_filtering, additional_filters)
#     248     return run_merge_job(
#     249         feature_vector,
#     250         target,
#    (...)
#     265         additional_filters=additional_filters,
#     266     )
#     268 merger = merger_engine(feature_vector, **(engine_args or {}))
# --> 269 return merger.start(
#     270     entity_rows,
#     271     entity_timestamp_column,
#     272     target=target,
#     273     drop_columns=drop_columns,
#     274     start_time=start_time,
#     275     end_time=end_time,
#     276     timestamp_for_filtering=timestamp_for_filtering,
#     277     with_indexes=with_indexes,
#     278     update_stats=update_stats,
#     279     query=query,
#     280     order_by=order_by,
#     281     additional_filters=additional_filters,
#     282 )
#
# File ~/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/feature_store/retrieval/base.py:128, in BaseMerger.start(self, entity_rows, entity_timestamp_column, target, drop_columns, start_time, end_time, timestamp_for_filtering, with_indexes, update_stats, query, order_by, additional_filters)
#     124 if start_time and not end_time:
#     125     # if end_time is not specified set it to now()
#     126     end_time = pd.Timestamp.now()
# --> 128 return self._generate_offline_vector(
#     129     entity_rows,
#     130     entity_timestamp_column,
#     131     feature_set_objects=feature_set_objects,
#     132     feature_set_fields=feature_set_fields,
#     133     start_time=start_time,
#     134     end_time=end_time,
#     135     timestamp_for_filtering=timestamp_for_filtering,
#     136     query=query,
#     137     order_by=order_by,
#     138     additional_filters=additional_filters,
#     139 )
#
# File ~/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/feature_store/retrieval/base.py:258, in BaseMerger._generate_offline_vector(self, entity_rows, entity_timestamp_column, feature_set_objects, feature_set_fields, start_time, end_time, timestamp_for_filtering, query, order_by, additional_filters)
#     255 if (start_time or end_time) and time_column:
#     256     timestamp_filtered = True
# --> 258 df = self._get_engine_df(
#     259     feature_set,
#     260     name,
#     261     column_names,
#     262     start_time if time_column else None,
#     263     end_time if time_column else None,
#     264     time_column,
#     265     additional_filters,
#     266 )
#     268 fs_entities_and_timestamp = list(feature_set.spec.entities.keys())
#     269 column_names += fs_entities_and_timestamp
#
# File ~/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/feature_store/retrieval/local_merger.py:119, in LocalFeatureMerger._get_engine_df(self, feature_set, feature_set_name, column_names, start_time, end_time, time_column, additional_filters)
#     109 def _get_engine_df(
#     110     self,
#     111     feature_set,
#    (...)
#     117     additional_filters=None,
#     118 ):
# --> 119     df = feature_set.to_dataframe(
#     120         columns=column_names,
#     121         start_time=start_time,
#     122         end_time=end_time,
#     123         time_column=time_column,
#     124         additional_filters=additional_filters,
#     125     )
#     126     if df.index.names[0]:
#     127         df.reset_index(inplace=True)
#
# File ~/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/feature_store/feature_set.py:969, in FeatureSet.to_dataframe(self, columns, df_module, target_name, start_time, end_time, time_column, additional_filters, **kwargs)
#     965 if not target:
#     966     raise mlrun.errors.MLRunNotFoundError(
#     967         "there are no offline targets for this feature set"
#     968     )
# --> 969 result = target.as_df(
#     970     columns=columns,
#     971     df_module=df_module,
#     972     entities=entities,
#     973     start_time=start_time,
#     974     end_time=end_time,
#     975     time_column=time_column,
#     976     additional_filters=additional_filters,
#     977     **kwargs,
#     978 )
#     979 return result
#
# File ~/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/datastore/targets.py:1018, in ParquetTarget.as_df(self, columns, df_module, entities, start_time, end_time, time_column, additional_filters, **kwargs)
#    1006 def as_df(
#    1007     self,
#    1008     columns=None,
#    (...)
#    1015     **kwargs,
#    1016 ):
#    1017     """return the target data as dataframe"""
# -> 1018     result = mlrun.get_dataitem(self.get_target_path()).as_df(
#    1019         columns=columns,
#    1020         df_module=df_module,
#    1021         format="parquet",
#    1022         start_time=start_time,
#    1023         end_time=end_time,
#    1024         time_column=time_column,
#    1025         additional_filters=transform_list_filters_to_tuple(additional_filters),
#    1026         **kwargs,
#    1027     )
#    1028     if not columns:
#    1029         drop_cols = []
#
# File ~/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/datastore/base.py:597, in DataItem.as_df(self, columns, df_module, format, time_column, start_time, end_time, additional_filters, **kwargs)
#     570 def as_df(
#     571     self,
#     572     columns=None,
#    (...)
#     579     **kwargs,
#     580 ):
#     581     """return a dataframe object (generated from the dataitem).
#     582
#     583     :param columns:     optional, list of columns to select
#    (...)
#     595                                 https://arrow.apache.org/docs/python/generated/pyarrow.parquet.ParquetDataset.html
#     596     """
# --> 597     df = self._store.as_df(
#     598         self._url,
#     599         self._path,
#     600         columns=columns,
#     601         df_module=df_module,
#     602         format=format,
#     603         time_column=time_column,
#     604         start_time=start_time,
#     605         end_time=end_time,
#     606         additional_filters=additional_filters,
#     607         **kwargs,
#     608     )
#     609     return df
#
# File ~/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/datastore/base.py:367, in DataStore.as_df(self, url, subpath, columns, df_module, format, start_time, end_time, time_column, additional_filters, **kwargs)
#     365     elif storage_options:
#     366         kwargs["storage_options"] = storage_options
# --> 367     df = reader(url, **kwargs)
#     368 else:
#     369     temp_file = tempfile.NamedTemporaryFile(delete=False)
#
# File ~/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/datastore/base.py:265, in DataStore._parquet_reader.<locals>.reader(*args, **kwargs)
#     263         return df_module.read_parquet(*args, **kwargs)
#     264 else:
# --> 265     return df_module.read_parquet(*args, **kwargs)
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/pandas/io/parquet.py:670, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     667     use_nullable_dtypes = False
#     668 check_dtype_backend(dtype_backend)
# --> 670 return impl.read(
#     671     path,
#     672     columns=columns,
#     673     filters=filters,
#     674     storage_options=storage_options,
#     675     use_nullable_dtypes=use_nullable_dtypes,
#     676     dtype_backend=dtype_backend,
#     677     filesystem=filesystem,
#     678     **kwargs,
#     679 )
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/pandas/io/parquet.py:272, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     265 path_or_handle, handles, filesystem = _get_path_or_handle(
#     266     path,
#     267     filesystem,
#     268     storage_options=storage_options,
#     269     mode="rb",
#     270 )
#     271 try:
# --> 272     pa_table = self.api.parquet.read_table(
#     273         path_or_handle,
#     274         columns=columns,
#     275         filesystem=filesystem,
#     276         filters=filters,
#     277         **kwargs,
#     278     )
#     279     result = pa_table.to_pandas(**to_pandas_kwargs)
#     281     if manager == "array":
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/pyarrow/parquet/core.py:3003, in read_table(source, columns, use_threads, metadata, schema, use_pandas_metadata, read_dictionary, memory_map, buffer_size, partitioning, filesystem, filters, use_legacy_dataset, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit)
#    2992         # TODO test that source is not a directory or a list
#    2993         dataset = ParquetFile(
#    2994             source, metadata=metadata, read_dictionary=read_dictionary,
#    2995             memory_map=memory_map, buffer_size=buffer_size,
#    (...)
#    3000             thrift_container_size_limit=thrift_container_size_limit,
#    3001         )
# -> 3003     return dataset.read(columns=columns, use_threads=use_threads,
#    3004                         use_pandas_metadata=use_pandas_metadata)
#    3006 warnings.warn(
#    3007     "Passing 'use_legacy_dataset=True' to get the legacy behaviour is "
#    3008     "deprecated as of pyarrow 8.0.0, and the legacy implementation will "
#    3009     "be removed in a future version.",
#    3010     FutureWarning, stacklevel=2)
#    3012 if ignore_prefixes is not None:
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/pyarrow/parquet/core.py:2631, in _ParquetDatasetV2.read(self, columns, use_threads, use_pandas_metadata)
#    2623         index_columns = [
#    2624             col for col in _get_pandas_index_columns(metadata)
#    2625             if not isinstance(col, dict)
#    2626         ]
#    2627         columns = (
#    2628             list(columns) + list(set(index_columns) - set(columns))
#    2629         )
# -> 2631 table = self._dataset.to_table(
#    2632     columns=columns, filter=self._filter_expression,
#    2633     use_threads=use_threads
#    2634 )
#    2636 # if use_pandas_metadata, restore the pandas metadata (which gets
#    2637 # lost if doing a specific `columns` selection in to_table)
#    2638 if use_pandas_metadata:
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/pyarrow/_dataset.pyx:547, in pyarrow._dataset.Dataset.to_table()
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/pyarrow/_dataset.pyx:393, in pyarrow._dataset.Dataset.scanner()
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/pyarrow/_dataset.pyx:3466, in pyarrow._dataset.Scanner.from_dataset()
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/pyarrow/_dataset.pyx:3384, in pyarrow._dataset.Scanner._make_scan_options()
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/pyarrow/_dataset.pyx:3335, in pyarrow._dataset._populate_builder()
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/pyarrow/error.pxi:91, in pyarrow.lib.check_status()
#
# ArrowInvalid: No match for FieldRef.Name(key2) in time: timestamp[us]
# bid: double
# ticker: string
# ask: dictionary<values=string, indices=int32, ordered=0>
# key: dictionary<values=string, indices=int32, ordered=0>
# __fragment_index: int32
# __batch_index: int32
# __last_in_fragment: bool
# __filename: string
